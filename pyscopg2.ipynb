# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Database credentials
user = "postgres"
password = "Admin"
host = "localhost"
port = "5432"
database = "MyDatabase"

# %%
# Create the database connection string
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')

# %%
# Load data from the 'customers' table into a pandas DataFrame
df = pd.read_sql('SELECT * FROM customers;', engine)

# %%
# Display the DataFrame
print(df)
# Out:
#    id           name                    email        city signup_date  \
# 0   1       Ali Khan       ali.khan@gmail.com      Lahore  2024-01-15
# 1   2     Sara Ahmed     sara.ahmed@yahoo.com     Karachi  2024-02-10
# 2   3    Usman Tariq  usman.tariq@hotmail.com   Islamabad  2024-03-05
# 3   4   Ayesha Malik   ayesha.malik@gmail.com  Faisalabad  2024-01-25
# 4   5  Bilal Hussain  bilal.hussain@yahoo.com      Multan  2024-02-18
# 5   6      Hina Raza      hina.raza@gmail.com  Rawalpindi  2024-03-12
# 6   7       Zain Ali     zain.ali@hotmail.com      Lahore  2024-01-30
# 7   8    Fatima Noor    fatima.noor@gmail.com     Karachi  2024-02-22
# 8   9   Hamza Sheikh   hamza.sheikh@yahoo.com   Islamabad  2024-03-15
# 9  10    Noor Hassan    noor.hassan@gmail.com    Peshawar  2024-02-05
#
#    total_spent
# 0     12500.50
# 1      8450.00
# 2     15600.75
# 3      6200.00
# 4      9800.20
# 5      4300.00
# 6     11200.00
# 7      7600.40
# 8     13400.90
# 9      5200.00
